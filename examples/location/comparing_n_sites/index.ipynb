# %% [markdown]
# ---
# title: "Marginal Gains - Exploring the Impact of the Number of Sites in a Solution"
# image: image.png
# toc: true
# execute:
#   enabled: true
# ---

# %%
import pandas as pd
import plotly.express as px
from lokigi.site import SiteProblem
import plotly.graph_objects as go
import numpy as np

# %% [markdown]
# First, let's set up our problem.

# %%
problem = SiteProblem()
problem.add_demand("../../../sample_data/brighton_demand.csv", demand_col="demand", location_id_col="LSOA")
problem.add_sites("../../../sample_data/brighton_sites_named.geojson", candidate_id_col="site")
problem.add_travel_matrix(
    travel_matrix_df="../../../sample_data/brighton_travel_matrix_driving_named.csv",
    source_col="LSOA",
    from_unit="seconds",
    to_unit="minutes"
    )
problem.add_region_geometry_layer("https://github.com/hsma-programme/h6_3d_facility_location_problems/raw/refs/heads/main/h6_3d_facility_location_problems/example_code/LSOA_2011_Boundaries_Super_Generalised_Clipped_BSC_EW_V4.geojson", common_col="LSOA11NM")

# %% [markdown]
# Let's explore the variation we see with a range of sites.
#
# :::{.callout-tip}
# We hope to release updates to lokigi to make this easier to do in future!
# :::
#
# One useful aspect of how lokigi handles solving is that we can solve the same problem multiple times without having to make copies of the problem object, so you can solve for p=1 all the way up to p=6 with no difficulty!

# %% [markdown]
# Let's go through and solve for every variant.
#
# :::{.callout-note}
# We could do this in a loop to be more efficient, but here we'll do it one by one for simplicity.
# :::

# %%
solutions_6 = problem.solve(p=6, objectives="p_median", threshold_for_coverage=10)
solutions_6.show_solutions().head(5)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#    solution_rank                                         site_names  \
# 0              1  [Dahlia (Site 1), Begonia (Site 2), Tulip (Sit...
#
#          site_indices  coverage_threshold  weighted_average  \
# 0  [0, 1, 2, 3, 4, 5]                  10              4.87
#
#    unweighted_average  90th_percentile    max  \
# 0                4.77             7.42  16.69
#
#    proportion_within_coverage_threshold  \
# 0                                  0.96
#
#                                           problem_df
# 0                         LSOA                  L...

# %%
solutions_5 = problem.solve(p=5, objectives="p_median", threshold_for_coverage=10)
solutions_5.show_solutions().head(5)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#    solution_rank                                         site_names  \
# 0              1  [Dahlia (Site 1), Tulip (Site 3), Daisy (Site ...
# 1              2  [Dahlia (Site 1), Begonia (Site 2), Tulip (Sit...
# 2              3  [Begonia (Site 2), Tulip (Site 3), Daisy (Site...
# 3              4  [Dahlia (Site 1), Begonia (Site 2), Tulip (Sit...
# 4              5  [Dahlia (Site 1), Begonia (Site 2), Tulip (Sit...
#
#       site_indices  coverage_threshold  weighted_average  unweighted_average  \
# 0  [0, 2, 3, 4, 5]                  10              4.96                4.88
# 1  [0, 1, 2, 3, 4]                  10              4.99                5.00
# 2  [1, 2, 3, 4, 5]                  10              5.02                4.93
# 3  [0, 1, 2, 3, 5]                  10              5.05                4.90
# 4  [0, 1, 2, 4, 5]                  10              5.97                5.79
#
#    90th_percentile    max  proportion_within_coverage_threshold  \
# 0             7.42  16.69                                  0.96
# 1             7.78  16.69                                  0.96
# 2             7.42  16.69                                  0.96
# 3             7.67  16.69                                  0.95
# 4             9.07  16.69                                  0.95
#
#                                           problem_df
# 0                         LSOA                  L...
# 1                         LSOA                  L...
# 2                         LSOA                  L...
# 3                         LSOA                  L...
# 4                         LSOA                  L...

# %%
solutions_4 = problem.solve(p=4, objectives="p_median", threshold_for_coverage=10)
solutions_4.show_solutions().head(5)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
#    solution_rank                                         site_names  \
# 0              1  [Dahlia (Site 1), Tulip (Site 3), Daisy (Site ...
# 1              2  [Tulip (Site 3), Daisy (Site 4), Daffodil (Sit...
# 2              3  [Begonia (Site 2), Tulip (Site 3), Daisy (Site...
# 3              4  [Dahlia (Site 1), Begonia (Site 2), Tulip (Sit...
# 4              5  [Dahlia (Site 1), Tulip (Site 3), Daisy (Site ...
#
#    site_indices  coverage_threshold  weighted_average  unweighted_average  \
# 0  [0, 2, 3, 4]                  10              5.08                5.12
# 1  [2, 3, 4, 5]                  10              5.11                5.05
# 2  [1, 2, 3, 5]                  10              5.20                5.07
# 3  [0, 1, 2, 3]                  10              5.22                5.21
# 4  [0, 2, 3, 5]                  10              5.23                5.19
#
#    90th_percentile    max  proportion_within_coverage_threshold  \
# 0             7.82  16.69                                  0.96
# 1             7.42  16.69                                  0.96
# 2             7.75  16.69                                  0.95
# 3             8.34  16.69                                  0.95
# 4             8.06  16.69                                  0.95
#
#                                           problem_df
# 0                         LSOA                  L...
# 1                         LSOA                  L...
# 2                         LSOA                  L...
# 3                         LSOA                  L...
# 4                         LSOA                  L...

# %%
solutions_3 = problem.solve(p=3, objectives="p_median", threshold_for_coverage=10)
solutions_3.show_solutions().head(5)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
#    solution_rank                                         site_names  \
# 0              1  [Tulip (Site 3), Daisy (Site 4), Daffodil (Sit...
# 1              2  [Tulip (Site 3), Daisy (Site 4), Snowdrop (Sit...
# 2              3  [Dahlia (Site 1), Tulip (Site 3), Daisy (Site 4)]
# 3              4  [Begonia (Site 2), Tulip (Site 3), Daisy (Site...
# 4              5  [Dahlia (Site 1), Tulip (Site 3), Snowdrop (Si...
#
#   site_indices  coverage_threshold  weighted_average  unweighted_average  \
# 0    [2, 3, 4]                  10              5.37                5.45
# 1    [2, 3, 5]                  10              5.38                5.36
# 2    [0, 2, 3]                  10              5.53                5.67
# 3    [1, 2, 3]                  10              5.54                5.59
# 4    [0, 2, 5]                  10              6.32                6.21
#
#    90th_percentile    max  proportion_within_coverage_threshold  \
# 0             8.50  16.69                                  0.95
# 1             8.06  16.69                                  0.95
# 2             9.36  16.69                                  0.93
# 3             9.00  16.69                                  0.94
# 4             9.33  16.69                                  0.94
#
#                                           problem_df
# 0                         LSOA                  L...
# 1                         LSOA                  L...
# 2                         LSOA                  L...
# 3                         LSOA                  L...
# 4                         LSOA                  L...

# %%
solutions_2 = problem.solve(p=2, objectives="p_median", threshold_for_coverage=10)
solutions_2.show_solutions()
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
#     solution_rank                              site_names site_indices  \
# 0               1        [Tulip (Site 3), Daisy (Site 4)]       [2, 3]
# 1               2     [Tulip (Site 3), Snowdrop (Site 6)]       [2, 5]
# 2               3       [Dahlia (Site 1), Tulip (Site 3)]       [0, 2]
# 3               4     [Daisy (Site 4), Daffodil (Site 5)]       [3, 4]
# 4               5      [Begonia (Site 2), Daisy (Site 4)]       [1, 3]
# 5               6     [Tulip (Site 3), Daffodil (Site 5)]       [2, 4]
# 6               7     [Daisy (Site 4), Snowdrop (Site 6)]       [3, 5]
# 7               8   [Begonia (Site 2), Snowdrop (Site 6)]       [1, 5]
# 8               9     [Dahlia (Site 1), Begonia (Site 2)]       [0, 1]
# 9              10  [Daffodil (Site 5), Snowdrop (Site 6)]       [4, 5]
# 10             11    [Dahlia (Site 1), Daffodil (Site 5)]       [0, 4]
# 11             12      [Begonia (Site 2), Tulip (Site 3)]       [1, 2]
# 12             13       [Dahlia (Site 1), Daisy (Site 4)]       [0, 3]
# 13             14   [Begonia (Site 2), Daffodil (Site 5)]       [1, 4]
# 14             15    [Dahlia (Site 1), Snowdrop (Site 6)]       [0, 5]
#
#     coverage_threshold  weighted_average  unweighted_average  90th_percentile  \
# 0                   10              5.94                6.21            10.46
# 1                   10              6.69                6.60             9.45
# 2                   10              6.81                6.88            10.19
# 3                   10              7.33                7.14            12.26
# 4                   10              7.46                7.31            11.93
# 5                   10              7.61                7.62            11.58
# 6                   10              8.23                7.85            13.72
# 7                   10              8.36                7.93            11.90
# 8                   10              8.45                8.15            11.98
# 9                   10              8.52                8.08            12.65
# 10                  10              8.56                8.20            12.65
# 11                  10              8.69                8.77            14.30
# 12                  10              9.19                8.96            15.21
# 13                  10              9.19                8.95            12.19
# 14                  10              9.39                8.86            14.26
#
#       max  proportion_within_coverage_threshold  \
# 0   16.69                                  0.87
# 1   16.69                                  0.92
# 2   16.69                                  0.88
# 3   21.71                                  0.79
# 4   23.92                                  0.79
# 5   16.69                                  0.72
# 6   22.86                                  0.67
# 7   22.86                                  0.78
# 8   23.92                                  0.75
# 9   21.71                                  0.76
# 10  21.71                                  0.72
# 11  16.69                                  0.59
# 12  26.33                                  0.58
# 13  21.71                                  0.59
# 14  22.86                                  0.65
#
#                                            problem_df
# 0                          LSOA                  L...
# 1                          LSOA                  L...
# 2                          LSOA                  L...
# 3                          LSOA                  L...
# 4                          LSOA                  L...
# 5                          LSOA                  L...
# 6                          LSOA                  L...
# 7                          LSOA                  L...
# 8                          LSOA                  L...
# 9                          LSOA                  L...
# 10                         LSOA                  L...
# 11                         LSOA                  L...
# 12                         LSOA                  L...
# 13                         LSOA                  L...
# 14                         LSOA                  L...

# %%
solutions_1 = problem.solve(p=1, objectives="p_median", threshold_for_coverage=10)
solutions_1.show_solutions()
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#    solution_rank           site_names site_indices  coverage_threshold  \
# 0              1     [Tulip (Site 3)]          [2]                  10
# 1              2  [Snowdrop (Site 6)]          [5]                  10
# 2              3  [Daffodil (Site 5)]          [4]                  10
# 3              4     [Daisy (Site 4)]          [3]                  10
# 4              5   [Begonia (Site 2)]          [1]                  10
# 5              6    [Dahlia (Site 1)]          [0]                  10
#
#    weighted_average  unweighted_average  90th_percentile    max  \
# 0              9.74               10.17            16.72  19.57
# 1              9.75                9.25            14.26  22.86
# 2              9.89                9.56            13.24  21.71
# 3              9.97                9.84            16.95  26.82
# 4             10.67               10.54            15.01  23.92
# 5             11.79               11.25            17.47  26.33
#
#    proportion_within_coverage_threshold  \
# 0                                  0.48
# 1                                  0.64
# 2                                  0.52
# 3                                  0.51
# 4                                  0.42
# 5                                  0.44
#
#                                           problem_df
# 0                         LSOA                  L...
# 1                         LSOA                  L...
# 2                         LSOA                  L...
# 3                         LSOA                  L...
# 4                         LSOA                  L...
# 5                         LSOA                  L...

# %% [markdown]
# Let's combine these into a single dataframe with the best solution for each (ranked on the weighted average).

# %%
all_sols = pd.concat(
    [solutions_1.solution_df.head(1),
     solutions_2.solution_df.head(1),
     solutions_3.solution_df.head(1),
     solutions_4.solution_df.head(1),
     solutions_5.solution_df.head(1),
     solutions_6.solution_df.head(1)
     ]
)

# %% [markdown]
# Let's now add a column containing the number of sites in each solution. We do this by counting the length of the 'site_indices' column.
#
# :::{.callout-note}
# Counting "site_names" would achieve the same thing!
# :::

# %%
all_sols["n_sites"] = all_sols["site_indices"].apply(lambda x: len(x))

# %% [markdown]
# Let's take a look at our final dataframe.

# %%
all_sols
# Out:
#    solution_rank                                         site_names  \
# 0              1                                   [Tulip (Site 3)]
# 0              1                   [Tulip (Site 3), Daisy (Site 4)]
# 0              1  [Tulip (Site 3), Daisy (Site 4), Daffodil (Sit...
# 0              1  [Dahlia (Site 1), Tulip (Site 3), Daisy (Site ...
# 0              1  [Dahlia (Site 1), Tulip (Site 3), Daisy (Site ...
# 0              1  [Dahlia (Site 1), Begonia (Site 2), Tulip (Sit...
#
#          site_indices  coverage_threshold  weighted_average  \
# 0                 [2]                  10          9.738592
# 0              [2, 3]                  10          5.943984
# 0           [2, 3, 4]                  10          5.372208
# 0        [0, 2, 3, 4]                  10          5.080178
# 0     [0, 2, 3, 4, 5]                  10          4.957668
# 0  [0, 1, 2, 3, 4, 5]                  10          4.868855
#
#    unweighted_average  90th_percentile        max  \
# 0           10.167285        16.720433  19.571000
# 0            6.207341        10.461133  16.688833
# 0            5.447841         8.503100  16.688833
# 0            5.115660         7.820333  16.688833
# 0            4.880920         7.417933  16.688833
# 0            4.765469         7.417933  16.688833
#
#    proportion_within_coverage_threshold  \
# 0                              0.484848
# 0                              0.866667
# 0                              0.945455
# 0                              0.957576
# 0                              0.957576
# 0                              0.957576
#
#                                           problem_df  n_sites
# 0                         LSOA                  L...        1
# 0                         LSOA                  L...        2
# 0                         LSOA                  L...        3
# 0                         LSOA                  L...        4
# 0                         LSOA                  L...        5
# 0                         LSOA                  L...        6

# %% [markdown]
# Let's now create a simple bar plot of the weighted average travel time of the best solution with each number of sites.

# %%
px.bar(all_sols, x="n_sites", y="weighted_average", title="Weighted average travel time by number of sites (Lower = Better)")
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.4.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="8dbe7cc3-cbd4-4436-a1f7-2648ed37d2d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8dbe7cc3-cbd4-4436-a1f7-2648ed37d2d8")) {                    Plotly.newPlot(                        "8dbe7cc3-cbd4-4436-a1f7-2648ed37d2d8",                        [{"hovertemplate":"n_sites=%{x}\u003cbr\u003eweighted_average=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUG"},"xaxis":"x","y":{"dtype":"f8","bdata":"l5Vkrih6I0BcNiHVo8YXQPRT\u002fBAkfRVA209WSRpSFEBbzqTqptQTQKSoOwy1eRNA"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":" ...

# %% [markdown]
# We can see that there are huge gains in average travel time when you move from 1 site to 2, but the gains beyond that for each additonal site are not so dramatic.

# %% [markdown]
# We can then create additional plots for different metrics.

# %%
px.bar(all_sols, x="n_sites", y="max", title="Maximum travel time by number of sites (Lower = Better)")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="7aff3a95-3d79-4c89-bf46-bc53465df0e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7aff3a95-3d79-4c89-bf46-bc53465df0e3")) {                    Plotly.newPlot(                        "7aff3a95-3d79-4c89-bf46-bc53465df0e3",                        [{"hovertemplate":"n_sites=%{x}\u003cbr\u003emax=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUG"},"xaxis":"x","y":{"dtype":"f8","bdata":"GARWDi2SM0C0D59hV7AwQLQPn2FXsDBAtA+fYVewMEC0D59hV7AwQLQPn2FXsDBA"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d": ...

# %%
px.bar(all_sols, x="n_sites", y="90th_percentile", title="90th percentile travel time by number of sites (Lower = Better)")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="288bdac8-c7e1-411b-b51e-2ca4a48a1cea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("288bdac8-c7e1-411b-b51e-2ca4a48a1cea")) {                    Plotly.newPlot(                        "288bdac8-c7e1-411b-b51e-2ca4a48a1cea",                        [{"hovertemplate":"n_sites=%{x}\u003cbr\u003e90th_percentile=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUG"},"xaxis":"x","y":{"dtype":"f8","bdata":"bJ2lUW64MEA2hhOrGewkQDY8vVKWASFA+\u002fAZdgVIH0C7TDq39qsdQLtMOrf2qx1A"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":"" ...

# %%
px.bar(all_sols, x="n_sites", y="proportion_within_coverage_threshold", title="% of LSOAs within 10 minutes travel time (driving) by number of sites (Higher = Better)")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="0fadff1a-0d11-4728-b6c6-51ce80b53a14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0fadff1a-0d11-4728-b6c6-51ce80b53a14")) {                    Plotly.newPlot(                        "0fadff1a-0d11-4728-b6c6-51ce80b53a14",                        [{"hovertemplate":"n_sites=%{x}\u003cbr\u003eproportion_within_coverage_threshold=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUG"},"xaxis":"x","y":{"dtype":"f8","bdata":"CB988MEH3z+8u7u7u7vrP0GeEuQpQe4\u002fpF5H6nWk7j+kXkfqdaTuP6ReR+p1pO4\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{" ...

# %% [markdown]
# ## Advanced plots
#
# These bar plots are a good start, but don't give a clear picture of the actual marginal gains.

# %% [markdown]
# Let's start by adding some useful extra data to our plots.

# %% [markdown]
# First, we'll add a marginal gain column. This will give us the improvement relative to the previous number of sites.
#
# For example, we know that the best solution for 1 site has a weighted average travel time of 9.7 minutes.
# The best solution for 2 sites has a weighted average travel time of 5.9 minutes.
# Therefore, the marginal gain is 3.8 minutes.

# %%
all_sols["marginal_gain"] = all_sols["weighted_average"].shift(1) - all_sols["weighted_average"]

# %% [markdown]
# We can then also calculate the relative gain - how much improvement there is relative to the first site.
#
# Here, we're saying that, for example

# %%
# Total possible improvement (1 site → max sites)
total_improvement = all_sols["weighted_average"].iloc[0] - all_sols["weighted_average"].iloc[-1]

# Cumulative improvement from baseline
all_sols["cumulative_improvement"] = all_sols["weighted_average"].iloc[0] - all_sols["weighted_average"]

# % of total achieved
all_sols["pct_of_total"] = all_sols["cumulative_improvement"] / total_improvement

all_sols["marginal_pct_total"] = all_sols["marginal_gain"] / total_improvement

# %%
all_sols
# Out:
#    solution_rank                                         site_names  \
# 0              1                                   [Tulip (Site 3)]
# 0              1                   [Tulip (Site 3), Daisy (Site 4)]
# 0              1  [Tulip (Site 3), Daisy (Site 4), Daffodil (Sit...
# 0              1  [Dahlia (Site 1), Tulip (Site 3), Daisy (Site ...
# 0              1  [Dahlia (Site 1), Tulip (Site 3), Daisy (Site ...
# 0              1  [Dahlia (Site 1), Begonia (Site 2), Tulip (Sit...
#
#          site_indices  coverage_threshold  weighted_average  \
# 0                 [2]                  10          9.738592
# 0              [2, 3]                  10          5.943984
# 0           [2, 3, 4]                  10          5.372208
# 0        [0, 2, 3, 4]                  10          5.080178
# 0     [0, 2, 3, 4, 5]                  10          4.957668
# 0  [0, 1, 2, 3, 4, 5]                  10          4.868855
#
#    unweighted_average  90th_percentile        max  \
# 0           10.167285        16.720433  19.571000
# 0            6.207341        10.461133  16.688833
# 0            5.447841         8.503100  16.688833
# 0            5.115660         7.820333  16.688833
# 0            4.880920         7.417933  16.688833
# 0            4.765469         7.417933  16.688833
#
#    proportion_within_coverage_threshold  \
# 0                              0.484848
# 0                              0.866667
# 0                              0.945455
# 0                              0.957576
# 0                              0.957576
# 0                              0.957576
#
#                                           problem_df  n_sites  marginal_gain  \
# 0                         LSOA                  L...        1            NaN
# 0                         LSOA                  L...        2       3.794607
# 0                         LSOA                  L...        3       0.571776
# 0                         LSOA                  L...        4       0.292029
# 0                         LSOA                  L...        5       0.122510
# 0                         LSOA                  L...        6       0.088813
#
#    cumulative_improvement  pct_of_total  marginal_pct_total
# 0                0.000000      0.000000                 NaN
# 0                3.794607      0.779222            0.779222
# 0                4.366384      0.896636            0.117414
# 0                4.658413      0.956605            0.059968
# 0                4.780924      0.981762            0.025158
# 0                4.869737      1.000000            0.018238

# %% [markdown]
# :::{.callout-tip}
# We've done this here for weighted average - but you could use the same code and apply it to any of the other metrics.
# :::

# %% [markdown]
# Now let's work on some additional plots.
#
# Perhaps the simplest option is just to plot the marginal gains as a line, which clearly shows the magnitude of the returns at each additional site number.

# %%
all_sols["high_value"] = all_sols["marginal_pct_total"] > 0.1  # tweak threshold
all_sols["n_sites_comparison"] = all_sols["n_sites"] - 1

fig = px.line(
    all_sols,
    x="n_sites",
    y="marginal_gain",
    markers=True,
    title="Diminishing Marginal Gains in Improvement to Demand-weighted Average Travel Time",
)

# Custom hover text
fig.update_traces(
    mode="lines+markers+text",
    hovertemplate=(
        "<b>%{x} sites</b><br>"
        "Marginal gain moving from %{customdata[3]} sites to %{customdata[2]} sites: %{y:.2f} minutes (%{customdata[1]:.1%} improvement) <br>"
        "Weighted average travel time for best solution with %{customdata[2]} sites: %{customdata[0]:.2f} minutes<br>"
        "% of total possible improvement achieved with %{customdata[2]} sites: %{customdata[4]:.1%}<extra></extra>"
    ),
    customdata=all_sols[["weighted_average", "marginal_pct_total", "n_sites", "n_sites_comparison", "pct_of_total"]].values,
    text=[
        f"{mg:.2f} minute improvement<br><i>{pct:.0%} improvement<br>vs {nst} site(s)</i>"
        for mg, pct,nst in zip(all_sols["marginal_gain"], all_sols["marginal_pct_total"], all_sols["n_sites_comparison"])
    ],
    textposition="top right",
     marker=dict(
        color=all_sols["marginal_pct_total"],  # continuous colour scale
        colorscale="BlueRed_r",
        showscale=False,
        colorbar=dict(title="% of total"),
        size=12
    )
)

fig.update_traces(

)

fig.update_layout(
    xaxis_title="Number of Sites",
    yaxis_title="Improvement from Adding Site<br>(Weighted Average Travel Time in Minutes)",
    template="plotly_white"
)

# We could optionally add in a line at the point the improvement from an additional
# site is below a certain percentage
# threshold_point = 0.1
# threshold = threshold_point * all_sols["marginal_gain"].iloc[1]
# elbow = all_sols[all_sols["marginal_gain"] < threshold].iloc[0]

# fig.add_vline(
#     x=elbow["n_sites"],
#     line_dash="dash",
#     annotation_text=f"Elbow ~ {int(elbow['n_sites'])} sites",
#     annotation_position="top"
# )

fig.update_yaxes(range=(
    0,
    np.nanmax(all_sols["marginal_gain"]*1.3)
    ))

fig.update_xaxes(range=(
    1.5,
    np.nanmax(all_sols["n_sites"]+1)
    ))


fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="7e40fba7-49ac-4d17-a0de-5283c95b998d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7e40fba7-49ac-4d17-a0de-5283c95b998d")) {                    Plotly.newPlot(                        "7e40fba7-49ac-4d17-a0de-5283c95b998d",                        [{"hovertemplate":"\u003cb\u003e%{x} sites\u003c\u002fb\u003e\u003cbr\u003eMarginal gain moving from %{customdata[3]} sites to %{customdata[2]} sites: %{y:.2f} minutes (%{customdata[1]:.1%} improvement) \u003cbr\u003eWeighted average travel time for best solution with %{customdata[2]} sites: %{customdata[0]:.2f} minutes\u003cbr\u003e% of total possible improvement achieved with %{customdata[2]} sites: %{customdata[4]:.1%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle","color":{"dtype":"f8","bdata":"AAAAAAAA+H+dDAF3Y+\u002foP2wFWQrcDr4\u002fbgbS1Se0rj+BeG5Y48KZP2LRZ\u002fLtrJI\u002f"},"colorbar":{"title":{"text":"% of total"}},"colorscale":[[0.0,"rgb(255,0,0)"],[1.0,"rgb(0,0,255)"]],"showscale":false,"size":12},"mode":"lines+markers+text","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AQIDBAUG"},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA+H+k6U8PW1sOQEATJyH+S+I\u002fkEFgepyw0j8AYGCs11y\u002fP8BtSZp3vLY\u002f"},"yaxis":"y","type":"scatter","customdata":{"dtype":"f8","bdata":"l5Vkrih6I0AAAAAAAAD4fwAAAAAAAPA\u002fAAAAAAAAAAAAAAAAAAAAAFw2IdWjxhdAnQwBd2Pv6D8AAAAAAAAAQAAAAAAAAPA\u002fnQwBd2Pv6D\u002f0U\u002fwQJH0VQGwFWQrcDr4\u002fAAAAAAAACEAAAAAAAAAAQEotTPg+sew\u002f209WSRpSFEBuBtLVJ7SuPwAAAAAAABBAAAAAAAAACECxTal1gZzuP1vOpOqm1BNAgXhuWOPCmT8AAAAAAAAUQAAAAAAAABBAdcFskJhq7z+kqDsMtXkTQGLRZ\u002fLtrJI\u002fAAAAAAAAGEAAAAAAAAAUQAAAAAAAAPA\u002f","shape":"6, 5"},"text":["nan minute improvement\u003cbr\u003e\u003ci\u003enan% improvement\u003cbr\u003evs 0 site(s)\u003c\u002fi\u003e","3.79 minute improvement\u003cbr\u003e\u003ci\u003e78% improvement\u003cbr\u003evs 1 site(s)\u003c\u002fi\u003e","0.57 minute improvement\u003cbr\u003e\u003ci\u003e12% improvement\u003cbr\u003evs 2 site(s)\u003c\u002fi\u003e","0.29 minute improvement\u003cbr\u003e\u003ci\u003e6% improvement\u003cbr\u003evs 3 site(s)\u003c\u002fi\u003e","0.12 minute improvement\u003cbr\u003e\u003ci\u003e3% improvement\u003cbr\u003evs 4 site(s)\u003c\u002fi\u003e","0.09 minute improvement\u003cbr\u003e\u003ci\u003e2% improvement\u003cbr\u003evs 5 site(s)\u003c\u002fi\u003e"],"textposition":"top right"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"hea ...

# %% [markdown]
# We can now clearly see that moving from 1 site to 2 sites reduces the weighted average travel time by nearly 4 minutes, but moving up to 3 sites from 2 sites only provides an average travel time reduction of around half a minute.

# %% [markdown]
# We can also plot this as the % of the theoretical maximum improvement achievable. By adding in a horizontal line at 1, we give a clear reference point with a diminishing area.

# %%
fig = px.line(
    all_sols,
    x="n_sites",
    y="pct_of_total",
    markers=True,
    title="Diminishing Marginal Gains"
)

fig.add_hline(y=1.0, line_dash="dash")

fig.update_traces(
    hovertemplate=(
        "<b>%{x} sites</b><br>"
        "Marginal gain moving from %{customdata[3]} sites to %{customdata[2]} sites: %{y:.2f} minutes (%{customdata[1]:.1%} improvement) <br>"
        "Weighted average travel time for best solution with %{customdata[2]} sites: %{customdata[0]:.2f} minutes<br>"
        "% of total possible improvement achieved with %{customdata[2]} sites: %{customdata[4]:.1%}<extra></extra>"
    ),
    customdata=all_sols[["weighted_average", "marginal_pct_total", "n_sites", "n_sites_comparison", "pct_of_total"]].values,
)

fig.update_layout(
    xaxis_title="Number of Sites",
    yaxis_title="Improvement from Adding Site<br>(% of total possible improvement)",
    template="plotly_white",
    yaxis=dict(tickformat=".0%")
)



fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="b40b361c-54f4-420a-ab53-c23a2e62c8a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b40b361c-54f4-420a-ab53-c23a2e62c8a9")) {                    Plotly.newPlot(                        "b40b361c-54f4-420a-ab53-c23a2e62c8a9",                        [{"hovertemplate":"\u003cb\u003e%{x} sites\u003c\u002fb\u003e\u003cbr\u003eMarginal gain moving from %{customdata[3]} sites to %{customdata[2]} sites: %{y:.2f} minutes (%{customdata[1]:.1%} improvement) \u003cbr\u003eWeighted average travel time for best solution with %{customdata[2]} sites: %{customdata[0]:.2f} minutes\u003cbr\u003e% of total possible improvement achieved with %{customdata[2]} sites: %{customdata[4]:.1%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AQIDBAUG"},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAACdDAF3Y+\u002foP0otTPg+sew\u002fsU2pdYGc7j91wWyQmGrvPwAAAAAAAPA\u002f"},"yaxis":"y","type":"scatter","customdata":{"dtype":"f8","bdata":"l5Vkrih6I0AAAAAAAAD4fwAAAAAAAPA\u002fAAAAAAAAAAAAAAAAAAAAAFw2IdWjxhdAnQwBd2Pv6D8AAAAAAAAAQAAAAAAAAPA\u002fnQwBd2Pv6D\u002f0U\u002fwQJH0VQGwFWQrcDr4\u002fAAAAAAAACEAAAAAAAAAAQEotTPg+sew\u002f209WSRpSFEBuBtLVJ7SuPwAAAAAAABBAAAAAAAAACECxTal1gZzuP1vOpOqm1BNAgXhuWOPCmT8AAAAAAAAUQAAAAAAAABBAdcFskJhq7z+kqDsMtXkTQGLRZ\u002fLtrJI\u002fAAAAAAAAGEAAAAAAAAAUQAAAAAAAAPA\u002f","shape":"6, 5"}}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"] ...

# %% [markdown]
# Another plot option is a waterfall plot.
#
# :::{.callout-warning}
# Consider the data literacy of your stakeholders - is this interpretable for them?
# :::

# %%
fig = go.Figure(go.Waterfall(
    x=all_sols["n_sites"],
    y=all_sols["marginal_gain"].fillna(0),
    measure=["absolute"] + ["relative"]*(len(all_sols)-1),
    text=[f"{v:.2f}" if pd.notna(v) else "" for v in all_sols["marginal_gain"]],
))

fig.update_layout(
    title="Marginal Improvement in Weighted Travel Time (Minutes) from Adding Sites",
    xaxis_title="Number of Sites",
    yaxis_title="Improvement in Weighted Average",
    template="plotly_white"
)

fig.update_yaxes(range=(0,6))


fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="c2c7cc27-0654-4d70-abb8-372262bb8d54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c2c7cc27-0654-4d70-abb8-372262bb8d54")) {                    Plotly.newPlot(                        "c2c7cc27-0654-4d70-abb8-372262bb8d54",                        [{"measure":["absolute","relative","relative","relative","relative","relative"],"text":["","3.79","0.57","0.29","0.12","0.09"],"x":{"dtype":"i1","bdata":"AQIDBAUG"},"y":{"dtype":"f8","bdata":"AAAAAAAAAACk6U8PW1sOQEATJyH+S+I\u002fkEFgepyw0j8AYGCs11y\u002fP8BtSZp3vLY\u002f"},"type":"waterfall"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":" ...
